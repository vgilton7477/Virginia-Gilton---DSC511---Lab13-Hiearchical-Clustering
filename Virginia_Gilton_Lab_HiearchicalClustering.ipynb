# %% [markdown]
# <a href="https://colab.research.google.com/github/vgilton7477/Virginia-Gilton---DSC511---Lab13-Hiearchical-Clustering/blob/main/Virginia_Gilton_Lab_HiearchicalClustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import linkage, dendrogram
from scipy.spatial.distance import pdist

from sklearn.cluster import AgglomerativeClustering #Scikit-learn version

# Generate a random dataset
np.random.seed(123)
data_matrix = np.random.randn(10, 10)  # 10 samples, 10 features

# %%
data_matrix
# Out:
# array([[-1.0856306 ,  0.99734545,  0.2829785 , -1.50629471, -0.57860025,
#          1.65143654, -2.42667924, -0.42891263,  1.26593626, -0.8667404 ],
#        [-0.67888615, -0.09470897,  1.49138963, -0.638902  , -0.44398196,
#         -0.43435128,  2.20593008,  2.18678609,  1.0040539 ,  0.3861864 ],
#        [ 0.73736858,  1.49073203, -0.93583387,  1.17582904, -1.25388067,
#         -0.6377515 ,  0.9071052 , -1.4286807 , -0.14006872, -0.8617549 ],
#        [-0.25561937, -2.79858911, -1.7715331 , -0.69987723,  0.92746243,
#         -0.17363568,  0.00284592,  0.68822271, -0.87953634,  0.28362732],
#        [-0.80536652, -1.72766949, -0.39089979,  0.57380586,  0.33858905,
#         -0.01183049,  2.39236527,  0.41291216,  0.97873601,  2.23814334],
#        [-1.29408532, -1.03878821,  1.74371223, -0.79806274,  0.02968323,
#          1.06931597,  0.89070639,  1.75488618,  1.49564414,  1.06939267],
#        [-0.77270871,  0.79486267,  0.31427199, -1.32626546,  1.41729905,
#          0.80723653,  0.04549008, -0.23309206, -1.19830114,  0.19952407],
#        [ 0.46843912, -0.83115498,  1.16220405, -1.09720305, -2.12310035,
#          1.03972709, -0.40336604, -0.12602959, -0.83751672, -1.60596276],
#        [ 1.25523737, -0.68886898,  1.66095249,  0.80730819, -0.31475815,
#         -1.0859024 , -0.73246199, -1.21252313,  2.08711336,  0.16444123],
#        [ 1.15020554, -1.26735205,  0.18103513,  1.17786194, -0.33501076,
#          1.03111446, -1.08456791, -1.36347154,  0.37940061, -0.37917643]])

# %%
# Perform hierarchical clustering using Scikit-learn
model = AgglomerativeClustering(n_clusters=3, linkage='ward')
labels = model.fit_predict(data_matrix)

# Compute linkage matrix for dendrogram
linkage_matrix = linkage(data_matrix, method='ward')

# Plot dendrogram
plt.figure(figsize=(8, 5))
dendrogram(linkage_matrix, labels=np.arange(1, 11), leaf_rotation=90)
plt.title("Hierarchical Clustering Dendrogram")
plt.xlabel("Sample Index")
plt.ylabel("Distance")
plt.show()

# %%
print(labels)
# Out:
# [2 0 1 0 0 0 2 2 1 1]

# %%
# Compute hierarchical clustering
row_linkage = linkage(pdist(data_matrix), method='complete')

# Create a heatmap with hierarchical clustering
sns.clustermap(data_matrix,
               method='complete',
               metric='euclidean',
               cmap="coolwarm",
               figsize=(8, 6))
plt.title("Hierarchical Clustering with Heatmap")
plt.show()

# %% [markdown]
# #Virginia Gilton
# #DSC511
# #Lab13-Hiearchical Clustering

# %% [markdown]
# To complete this lab, I used hints from resources, and my work from Lab 8 assignment. I also utilized hints from Dr. Bisgin's GitHub datamining resources shared - Pandas_In_Class_Notebook.ipynb.

# %%
import pandas as pd
#please read log_top_counts_nash.csv from the DATA folder and make sure that you reset your index to the first column which goes by "Genes"
#use head() to make sure you have Genes set index (gene names should work like rownames in R)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Import data
import csv

# Open .csv file
with open('/content/drive/MyDrive/DATA/log_top_counts_nash.csv') as f:
  reader = csv.DictReader(f)
  genes_data = list(reader)

# %%
# Please read log_top_counts_nash.csv from the DATA folder:

# Reading the data .csv file
data = pd.read_csv('/content/drive/MyDrive/DATA/log_top_counts_nash.csv', index_col=0)

# Use head() to make sure you have Genes set index (gene names should work like rownames in R)
# Read data as DataFrame

df = pd.DataFrame(genes_data)
df.head()
print(data.shape)
data.head()
# Out:
# (20, 10)
#               C_S27     C_S28     C_S31     C_S43     C_S48     N_S29  \
# Genes
# MYH4       0.000000  0.000000  1.330235  0.000000  1.101345  7.592200
# LINC01595  2.157668  3.625286  4.657125  1.927655  4.889408  4.472845
# X          1.449411  0.675228  0.000000  0.000000  1.718566  2.944198
# CD300LG    1.449411  1.133365  0.813294  3.434998  1.718566  5.855990
# CDH15      1.449411  1.480548  3.334371  0.000000  0.000000  5.011237
#
#               N_S30     N_S37      N_S38     N_S46
# Genes
# MYH4       8.363149  0.000000   2.151516  1.956310
# LINC01595  9.460346  9.281353  12.170895  5.762683
# X          1.754675  2.888432   6.720223  4.750935
# CD300LG    6.837722  0.000000   4.582132  5.600842
# CDH15      3.686222  3.406941   4.582132  6.964275

# %%
# Make sure that you reset your index to the first column which goes by "Genes":

for index in range(1):
  print(genes_data[index])
# Out:
# {'Genes': 'MYH4', 'C_S27': '0', 'C_S28': '0', 'C_S31': '1.330235356', 'C_S43': '0', 'C_S48': '1.101344721', 'N_S29': '7.59219961', 'N_S30': '8.363148819', 'N_S37': '0', 'N_S38': '2.151515539', 'N_S46': '1.956309745'}

# %%
#please use seaborns clustermap feature to create a heatmap for gene counts from the NASH patients.

# %%
# Please use seaborns clustermap feature to create a heatmap for gene counts from the NASH patients.

# Compute hierarchical clustering
row_linkage = linkage(pdist(data_matrix), method='complete')

# Create a heatmap with hierarchical clustering
sns.clustermap(data,
               method='complete',
               metric='euclidean',
               cmap="coolwarm",
               figsize=(8, 6))
plt.title("Hierarchical Clustering with Heatmap - Gene Counts from NASH Patients")
plt.show()

# %% [markdown]
# Above ^^ took out data_matrix in sns.clustermap command - and just left data to get x and y values to appear in hierarchical clustering map.
